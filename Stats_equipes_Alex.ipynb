# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
from pprint import pprint

# %%
url = requests.get("https://top14.lnr.fr/club/toulon/statistiques")

# %%
url
# Out:
# <Response [200]>

# %%
print(url.text)
# Out:
# <!DOCTYPE html>
# <html lang="fr">
# <head>
#   <meta charset="utf-8" />
#   <meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1" />
#   <meta name="csrf-token" content="gLsmVVr4j7p2IwEu2UyFl31VcCMcS8sV7FFy7BE8" />
#
#   <title>RC Toulon - RCT | Top 14 - Site Officiel</title>
#   <meta name="title" content="RC Toulon - RCT | Top 14 - Site Officiel" />
#   <meta name="description" content="Découvrez toutes les informations du RC Toulon - RCT : Résultats, Effectif et Statistiques" />
#       <meta property="og:type" content="website" />
#       <meta property="og:site_name" content="Ligue Nationale de Rugby" />
#       <meta property="og:locale" content="fr" />
#       <meta property="og:url" content="https://top14.lnr.fr/club/toulon/statistiques" />
#       <meta property="og:title" content="RC Toulon - RCT | Top 14 - Site Officiel" />
# ...

# %%
soup = BeautifulSoup(url.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="fr">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="gLsmVVr4j7p2IwEu2UyFl31VcCMcS8sV7FFy7BE8" name="csrf-token"/>
# <title>RC Toulon - RCT | Top 14 - Site Officiel</title>
# <meta content="RC Toulon - RCT | Top 14 - Site Officiel" name="title"/>
# <meta content="Découvrez toutes les informations du RC Toulon - RCT : Résultats, Effectif et Statistiques" name="description"/>
# <meta content="website" property="og:type"/>
# <meta content="Ligue Nationale de Rugby" property="og:site_name"/>
# <meta content="fr" property="og:locale"/>
# <meta content="https://top14.lnr.fr/club/toulon/statistiques" property="og:url"/>
# <meta content="RC Toulon - RCT | Top 14 - Site Officiel" property="og:title"/>
# <meta content="Découvrez toutes les informations du RC Toulon - RCT : Résultats, Effectif et Statistiques" property="og:description"/>
# ...

# %%
# joueur= soup.find_all('div',{'class':'club-statistics__players-wrapper'})
# joueur

# %%
stats = soup.find_all('div', {'class': 'club-statistics__container'})
stats=(stats[0].find_all('club-season-stats'))[0]
stats
# Out:
# <club-season-stats :stats='{"rank":3,"history":[{"result":"V","victory":true},{"result":"V","victory":true},{"result":"V","victory":true},{"result":"D","victory":false},{"result":"V","victory":true}],"scoredPoints":{"total":363,"tries":43,"penalties":27},"concededPoints":{"total":303,"tries":33,"penalties":28},"wins":{"count":9,"percentage":64},"matchesCount":14,"bonus":{"total":7,"defensive":3,"offensive":4},"yellowCardsCount":12,"redCardsCount":1,"biggestWinFixture":{"hostingClub":{"id":77,"name":"RC Toulon","logo":{"original":"https:\/\/cdn.lnr.fr\/club\/toulon\/photo\/logo.4c337c42a687a237af970fc3b1777f358bc8cdda","thumbnail-1x":"https:\/\/cdn.lnr.fr\/club\/toulon\/photo\/logo-thumbnail-1x.4c337c42a687a237af970fc3b1777f358bc8cdda","thumbnail-2x":"https:\/\/cdn.lnr.fr\/club\/toulon\/photo\/logo-thumbnail-2x.4c337c42a687a237af970fc3b1777f358bc8cdda"},"url":"https:\/\/top14.lnr.fr\/club\/toulon","acronym":"RCT","score":54,"isCurrentClub":true},"visitingClub":{"id":84,"name":"RC Vann
# ...

# %% [markdown]
# ## Classement de l'équipes

# %%
classement=int(str(stats).split(":")[2].split(',')[0])
classement
# Out:
# 3

# %% [markdown]
# ## Historique dernier match

# %%
list_histo=str(stats).split(":")[4:13]
list_histo
# Out:
# ['"V","victory"',
#  'true},{"result"',
#  '"V","victory"',
#  'true},{"result"',
#  '"V","victory"',
#  'true},{"result"',
#  '"D","victory"',
#  'false},{"result"',
#  '"V","victory"']

# %%
list_histo[8].split(",")[0]
# Out:
# '"V"'

# %%
listnb=[0,2,4,6,8]

# %%
list_histo2=[]

for ele in listnb:
    list_histo2.append(list_histo[ele].split(",")[0])
    
list_histo2
# Out:
# ['"V"', '"V"', '"V"', '"D"', '"V"']

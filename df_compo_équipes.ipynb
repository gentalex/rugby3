# %%
from pprint import pprint
import numpy as np

# %%
# WS des équipes de rugby

from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

url = 'https://www.ultimaterugby.com/app/public/index.php/lyon/squad'

html = requests.get(url)

soup = BeautifulSoup(html.text, 'html.parser')

test = soup.find_all('div', {"class" : "col-md-2 col-sm-4 col-xs-6"})

print(str(test[0].find_all('h4')[0].get_text(separator='<br/>')).replace("<br/>"," "))

# for player in range(10):
#     print(test[player].find_all('div', {'class' : "front"})[0].get_text())
# Out:
# Jermaine Ainsley

# %%
dico_club = {'toulouse':'toulouse',
             'bordeaux':'union-bordeaux-bègles',
             'toulon':'rc-toulon',
             'clermont':'clermont',
             'bayonne':'bayonne',
             'montpellier':'montpellier',
             'castres':'castres-olympique',
             'racing':'racing-92',
             'lyon':'lyon',
             'pau':'pau',
             'perpignan':'perpignan',
             'stade-francais':'stade-francais',
             'vannes':'vannes',
             'france':'france'}

# %%
club = input().lower()

url = f'https://www.ultimaterugby.com/app/public/index.php/{dico_club[club]}/squad'

html = requests.get(url)

soup = BeautifulSoup(html.text, 'html.parser')

test = soup.find_all('div', {"class" : "col-md-2 col-sm-4 col-xs-6"})

for player in range(len(test)):
    print(str(test[player].find_all('h4')[0].get_text(separator='<br/>')).replace("<br/>"," "))
# Out:
# Paul Abadie
# Zaccharie Affane
# Louis Bielle-Biarrey
# Pierre Bochaton
# Ugo Boniface
# Yannick Bru
# Romain Buros
# Joey Carbery
# Cyril Cazeaux
# Adam Coleman
# Santiago Cordero
# Nicolas Depoortere
# Mahamadou Diaby
# Nans Ducuing
# Joseph Exshaw
# Sipili Falatea
# Mateo Garcia
# Romain Gardrat
# Marko Gazzotti
# Renato Giammarioli
# Jonny Gray
# Tiaan Jacobs
# Matthieu Jalibert
# Rohan Janse van Rensburg
# Jean-Baptiste Lachaise
# Remi Lamerat
# Maxime Lamothe
# Romain Latterrade
# Romain Lescarret
# Yann Lesgourgues
# Maxime Lucu
# Gatien Massé
# Temo Matiu
# Noel McNamara
# Yoram Moefana
# Jacques Nguimbous
# Gabriel Oghre
# Damian Penaud
# Matis Perchaud
# Sirius Permal
# Guido Petti
# Jefferson Poirot
# Arthur Retiere
# Enzo Reybier
# Alexandre Ricard
# Alban Roussel
# Connor Sa
# Carlu Sadie
# Mateo Saint-Germain
# Pete Samu
# Shaun Sowerby
# Lachlan Swinton
# Ben Tameifuna
# Ben Tapuai
# Tevita Tatafu.
# Toma Taufa
# Pablo Uberti
# Bastien Vergnes Taillefer
# Tom Willis

# %%
club = input().lower()

url = f'https://www.ultimaterugby.com/app/public/index.php/{dico_club[club]}/squad'

html = requests.get(url)

soup = BeautifulSoup(html.text, 'html.parser')

test = soup.find_all('div', {"class" : "col-md-2 col-sm-4 col-xs-6"})

# for player in range(len(test)):
for player in range(3): # test avec 3 pour plus de lisibilité
    print(str(test[player].find_all('h4')[0].get_text(separator='<br/>')).replace("<br/>"," "))
    print(test[player].find_all('b'))
    try:
        print(test[player].find_all('li')[0].get_text())
        print(test[player].find_all('li')[1].get_text())
        print(test[player].find_all('li')[2].get_text())
        print('---')
    # print(test[player].find_all('b'))
    except IndexError:
        pass
# Out:
# Paul Abadie
# [<b>Scrum Half</b>]
# Jul 28, 1994
# 1.76m
# 88kg
# ---
# Zaccharie Affane
# [<b>Tighthead Prop</b>]
# Jul 15, 2004
# 1.91m
# 126kg
# ---
# Louis Bielle-Biarrey
# [<b>Left Wing</b>]
# Jun 19, 2003
# 1.84m
# 79kg
# ---

# %%
url = 'https://www.ultimaterugby.com/app/public/index.php/union-bordeaux-bègles/squad'

html = requests.get(url)

soup = BeautifulSoup(html.text, 'html.parser')

test = soup.find_all('div', {"class" : "col-md-2 col-sm-4 col-xs-6"})

for player in range(len(test)):
# for player in range(3): # test avec 3 pour plus de lisibilité
    print(str(test[player].find_all('h4')[0].get_text(separator='<br/>')).replace("<br/>"," "))
    print(test[player].find_all('b')[0].get_text())
    try:
        print([test[player].find_all('li')[ele].get_text() for ele in range(len(test[player].find_all('li')))])
            # print(test[player].find_all('li')[ele].get_text())
            # print(test[player].find_all('li')[1].get_text())
            # print(test[player].find_all('li')[2].get_text())
        print('---')
    # print(test[player].find_all('b'))
    except IndexError:
        pass
# Out:
# Paul Abadie
# Scrum Half
# ['Jul 28, 1994', '1.76m', '88kg']
# ---
# Zaccharie Affane
# Tighthead Prop
# ['Jul 15, 2004', '1.91m', '126kg']
# ---
# Louis Bielle-Biarrey
# Left Wing
# ['Jun 19, 2003', '1.84m', '79kg']
# ---
# Pierre Bochaton
# No 4 Lock
# ['Apr 17, 2001', '1.97m', '103kg']
# ---
# Ugo Boniface
# Tighthead Prop
# ['Jul 21, 1998', '1.90m', '125kg']
# ---
# Yannick Bru
# Head Coach
# ['May 22, 1973', '1.80m', '99kg']
# ---
# Romain Buros
# Fullback
# ['Jul 31, 1997', '1.87m', '97kg']
# ---
# Joey Carbery
# Fly Half
# ['Nov 1, 1995', '1.83m', '88kg']
# ---
# Cyril Cazeaux
# No 4 Lock
# ['Feb 10, 1995', '1.98m', '117kg']
# ---
# Adam Coleman
# No 4 Lock
# ['Oct 7, 1991', '2.04m', '122kg']
# ---
# Santiago Cordero
# Left Wing
# ['Dec 6, 1993', '1.75m', '83kg']
# ---
# Nicolas Depoortere
# Outside Centre
# ['Jan 1, 2003', '1.93m', '87kg']
# ---
# Mahamadou Diaby
# Blindside Flanker
# ['Aug 15, 1990', '1.92m', '104kg']
# ---
# Nans Ducuing
# Fullback
# ['Nov 6, 1991', '1.85m', '90kg']
# ---
# Joseph Exshaw
# Scrum Half
# ['Feb 10, 2003', '1.80m', '83kg']
# ---
# Sipili Falatea
# Tighthead Prop
# ['Jun 23, 1997', '1.84m', '114kg']
# ---
# Mateo Garcia
# Fly Half
# ['Jul 8, 2002', '1.74m', '79kg']
# ---
# Romain Gardrat
# Blindside Flanker
# ['1.78m', '88kg']
# ---
# Marko Gazzotti
# Blindside Flanker
# ['Sep 24, 2004', '1.92m', '107kg']
# ---
# Renato Giammarioli
# Openside Flanker
# ['Mar 23, 1995', '1.88m', '111kg']
# ---
# Jonny Gray
# No 5 Lock
# ['Mar 14, 1994', '1.98m', '122kg']
# ---
# Tiaan Jacobs
# Openside Flanker
# ['Aug 16, 2004', '1.93m', '107kg']
# ---
# Matthieu Jalibert
# Fly Half
# ['Nov 6, 1998', '1.84m', '84kg']
# ---
# Rohan Janse van Rensburg
# Inside Centre
# ['Sep 11, 1994', '1.85m', '109kg']
# ---
# Jean-Baptiste Lachaise
# Blindside Flanker
# ['Apr 26, 2001', '1.90m', '98kg']
# ---
# Remi Lamerat
# Outside Centre
# ['Jan 14, 1990', '1.84m', '106kg']
# ---
# Maxime Lamothe
# Hooker
# ['Oct 3, 1998', '1.83m', '109kg']
# ---
# Romain Latterrade
# Hooker
# ['Apr 4, 1996', '1.79m', '112kg']
# ---
# Romain Lescarret
# Loosehead Prop
# ['Feb 23, 1993']
# ---
# Yann Lesgourgues
# Scrum Half
# ['Jan 17, 1991', '1.77m', '76kg']
# ---
# Maxime Lucu
# Scrum Half
# ['Jan 12, 1993', '1.77m', '91kg']
# ---
# Gatien Massé
# Left Wing
# ['May 2, 2002', '1.82m', '93kg']
# ---
# Temo Matiu
# No 4 Lock
# ['Jul 20, 2001', '1.91m', '100kg']
# ---
# Noel McNamara
# Coach
# []
# ---
# Yoram Moefana
# Outside Centre
# ['Jul 18, 2000', '1.82m', '97kg']
# ---
# Jacques Nguimbous
# No 4 Lock
# []
# ---
# Gabriel Oghre
# Hooker
# ['May 25, 1998', '1.72m', '103kg']
# ---
# Damian Penaud
# Right Wing
# ['Sep 25, 1996', '1.92m', '94kg']
# ---
# Matis Perchaud
# Loosehead Prop
# ['Sep 17, 2002', '1.87m', '114kg']
# ---
# Sirius Permal
# Openside Flanker
# ['Oct 9, 2003', '1.87m', '107kg']
# ---
# Guido Petti
# No 4 Lock
# ['Nov 17, 1994', '1.94m', '110kg']
# ---
# Jefferson Poirot
# Loosehead Prop
# ['Nov 1, 1992', '1.81m', '117kg']
# ---
# Arthur Retiere
# Scrum Half
# ['Aug 1, 1997', '1.70m', '80kg']
# ---
# Enzo Reybier
# Left Wing
# ['Apr 4, 2002', '1.74m', '76kg']
# ---
# Alexandre Ricard
# Blindside Flanker
# ['Mar 23, 1984', '2.00m', '111kg']
# ---
# Alban Roussel
# No 4 Lock
# ['Nov 9, 1998', '1.96m', '120kg']
# ---
# Connor Sa
# Hooker
# ['Jan 22, 2002', '1.83m', '101kg']
# ---
# Carlu Sadie
# Tighthead Prop
# ['May 7, 1997', '1.82m', '138kg']
# ---
# Mateo Saint-Germain
# Hooker
# ['Feb 12, 2002', '1.81m', '104kg']
# ---
# Pete Samu
# Blindside Flanker
# ['Dec 17, 1991', '1.85m', '102kg']
# ---
# Shaun Sowerby
# Head Coach
# ['Jul 1, 1978', '1.95m', '108kg']
# ---
# Lachlan Swinton
# Blindside Flanker
# ['Jan 16, 1997', '1.94m', '113kg']
# ---
# Ben Tameifuna
# Tighthead Prop
# ['Aug 30, 1991', '1.82m', '148kg']
# ---
# Ben Tapuai
# Outside Centre
# ['Jan 19, 1989', '1.80m', '100kg']
# ---
# Tevita Tatafu.
# No. 8
# ['Jan 2, 1996', '1.83m', '133kg']
# ---
# Toma Taufa
# Tighthead Prop
# ['Mar 9, 1995', '1.78m', '124kg']
# ---
# Pablo Uberti
# Inside Centre
# ['Oct 19, 1997', '1.85m', '85kg']
# ---
# Bastien Vergnes Taillefer
# Blindside Flanker
# ['Jun 13, 1997', '1.92m', '108kg']
# ---
# Tom Willis
# No. 8
# ['Jan 18, 1999', '1.92m', '117kg']
# ---

# %%
# On remplace les listes vides par des np.nan qu'on dégage du df par là suite
# Etape suivante : on créer les colonnes en récupérant les index de chaque liste (ex : index 0 = date de naissance)
# On a créer nos dico, on peut créer le DF et en faire ce qu'on veut

# %%
club = input().lower()

liste_stats = []
liste_nom = []
liste_poste = []

url = f'https://www.ultimaterugby.com/app/public/index.php/{dico_club[club]}/squad'

html = requests.get(url)

soup = BeautifulSoup(html.text, 'html.parser')

test = soup.find_all('div', {"class" : "col-md-2 col-sm-4 col-xs-6"})

for player in range(len(test)):
# for player in range(3): # test avec 3 pour plus de lisibilité
    name = str(test[player].find_all('h4')[0].get_text(separator='<br/>')).replace("<br/>"," ")
    # print(name)
    liste_nom.append(name)
    poste = test[player].find_all('b')[0].get_text()
    # print(poste)
    liste_poste.append(poste)
    try:
        stats = ([test[player].find_all('li')[ele].get_text() for ele in range(len(test[player].find_all('li')))])
        # print(stats)
        if len(stats) == 3:
            # print(len(stats))
            liste_stats.append(stats)
        else:
            liste_stats.append(np.nan)
        # print('---')
    # print(test[player].find_all('b'))
    except IndexError:
        pass
    
df_rugby = pd.DataFrame({
    
    "Nom":liste_nom,
    "Poste":liste_poste,
    "Stats":liste_stats
})
# print(len(liste_nom))
# print(len(liste_poste))
# print(len(liste_stats))
df_rugby.dropna().sample(3)
# Out:
#                      Nom           Poste                         Stats
# 9   Pierre-Louis Barassi  Outside Centre  [Apr 22, 1998, 1.87m, 102kg]
# 35        Blair Kinghorn        Fullback  [Jan 18, 1997, 1.93m, 107kg]
# 47              Ugo Mola      Head Coach   [May 14, 1973, 1.83m, 85kg]

# %%
df_rugby.loc[0]['Stats'][0][-4:]
# Out:
# '1992'

# %%
# FONCTION OK

def fn_df_club(ville):

    liste_stats = []
    liste_nom = []
    liste_poste = []
    
    club = ville.lower()

    url = f'https://www.ultimaterugby.com/app/public/index.php/{dico_club[club]}/squad'

    html = requests.get(url)

    soup = BeautifulSoup(html.text, 'html.parser')

    test = soup.find_all('div', {"class" : "col-md-2 col-sm-4 col-xs-6"})

    for player in range(len(test)):
    # for player in range(3): # test avec 3 pour plus de lisibilité
        name = str(test[player].find_all('h4')[0].get_text(separator='<br/>')).replace("<br/>"," ")
        # print(name)
        liste_nom.append(name)
        poste = test[player].find_all('b')[0].get_text()
        # print(poste)
        liste_poste.append(poste)
        try:
            stats = ([test[player].find_all('li')[ele].get_text() for ele in range(len(test[player].find_all('li')))])
            # print(stats)
            if len(stats) == 3:
                # print(len(stats))
                liste_stats.append(stats)
            else:
                liste_stats.append(np.nan)
            # print('---')
        # print(test[player].find_all('b'))
        except IndexError:
            pass
        
    df_rugby_fn = pd.DataFrame({
        
        "Nom":liste_nom,
        "Poste":liste_poste,
        "Stats":liste_stats
    })
    # print(len(liste_nom))
    # print(len(liste_poste))
    # print(len(liste_stats))
    
    # Faire les modifications du df avant de le return
    # df_rugby_fn['Age'] = df_rugby_fn['Stats'].apply(lambda x : x[0])
    df_rugby_fn = df_rugby_fn.dropna()
    df_rugby_fn['Age'] = df_rugby_fn['Stats'].apply(lambda x : 2025-int(x[0][-4:]))
    df_rugby_fn['Taille (m)'] = df_rugby_fn['Stats'].apply(lambda x : x[1][0:4])
    df_rugby_fn['Poids (kg)'] = df_rugby_fn['Stats'].apply(lambda x : x[2][:-2])
    
    return df_rugby_fn.dropna()

# %%
# Nouvelle cellule avec dico intégré

def fn_df_club(ville):
    
    dico_club = {'toulouse':'toulouse',
             'bordeaux':'union-bordeaux-bègles',
             'toulon':'rc-toulon',
             'clermont':'clermont',
             'bayonne':'bayonne',
             'montpellier':'montpellier',
             'castres':'castres-olympique',
             'racing':'racing-92',
             'lyon':'lyon',
             'pau':'pau',
             'perpignan':'perpignan',
             'stade-francais':'stade-francais',
             'vannes':'vannes',
             'france':'france'}

    liste_stats = []
    liste_nom = []
    liste_poste = []
    
    club = ville.lower()

    url = f'https://www.ultimaterugby.com/app/public/index.php/{dico_club[club]}/squad'

    html = requests.get(url)

    soup = BeautifulSoup(html.text, 'html.parser')

    test = soup.find_all('div', {"class" : "col-md-2 col-sm-4 col-xs-6"})

    for player in range(len(test)):
    # for player in range(3): # test avec 3 pour plus de lisibilité
        name = str(test[player].find_all('h4')[0].get_text(separator='<br/>')).replace("<br/>"," ")
        # print(name)
        liste_nom.append(name)
        poste = test[player].find_all('b')[0].get_text()
        # print(poste)
        liste_poste.append(poste)
        try:
            stats = ([test[player].find_all('li')[ele].get_text() for ele in range(len(test[player].find_all('li')))])
            # print(stats)
            if len(stats) == 3:
                # print(len(stats))
                liste_stats.append(stats)
            else:
                liste_stats.append(np.nan)
            # print('---')
        # print(test[player].find_all('b'))
        except IndexError:
            pass
        
    df_rugby_fn = pd.DataFrame({
        
        "Nom":liste_nom,
        "Poste":liste_poste,
        "Stats":liste_stats
    })
    # print(len(liste_nom))
    # print(len(liste_poste))
    # print(len(liste_stats))
    
    # Faire les modifications du df avant de le return
    # df_rugby_fn['Age'] = df_rugby_fn['Stats'].apply(lambda x : x[0])
    df_rugby_fn = df_rugby_fn.dropna()
    df_rugby_fn['Age'] = df_rugby_fn['Stats'].apply(lambda x : 2025-int(x[0][-4:]))
    df_rugby_fn['Taille (m)'] = df_rugby_fn['Stats'].apply(lambda x : x[1][0:4])
    df_rugby_fn['Poids (kg)'] = df_rugby_fn['Stats'].apply(lambda x : x[2][:-2])
    
    return df_rugby_fn.dropna()

fn_df_club('toulouse')
# Out:
#                        Nom              Poste                         Stats  \
# 0                Pita Ahki      Inside Centre   [Sep 24, 1992, 1.89m, 96kg]
# 1             David Ainu'u     Loosehead Prop  [Nov 20, 1999, 1.78m, 125kg]
# 4         Dorian Aldegheri     Tighthead Prop   [Aug 4, 1993, 1.80m, 119kg]
# 5            Richie Arnold          No 5 Lock   [Jul 1, 1990, 2.08m, 127kg]
# 6              Paul Ausset              No. 8  [Jun 19, 1999, 1.90m, 100kg]
# 7             Cyril Baille     Loosehead Prop  [Sep 15, 1993, 1.82m, 116kg]
# 8                Leo Banos   Openside Flanker  [Aug 16, 2002, 1.91m, 112kg]
# 9     Pierre-Louis Barassi     Outside Centre  [Apr 22, 1998, 1.87m, 102kg]
# 11     Setareki Bituniyata     Outside Centre  [Aug 12, 1995, 1.94m, 112kg]
# 12         Arthur Bonneval          Left Wing   [May 31, 1995, 1.82m, 88kg]
# 13           Jean Bouilhou    Assistant Coach   [Dec 1, 1978, 1.93m, 100kg]
# 14          Joshua Brennan          No 5 Lock  [Nov 28, 2001, 1.99m, 114kg]
# 15           Ange Capuozzo           Fullback   [Apr 30, 1999, 1.77m, 82kg]
# 16  Mathis Castro Ferreira          Left Wing  [Jan 13, 2004, 1.92m, 105kg]
# 17     Santiago Chocobares     Outside Centre   [Mar 31, 1999, 1.88m, 96kg]
# 18             Paul Costes      Inside Centre    [Apr 4, 2003, 1.82m, 85kg]
# 19       Guillaume Cramont             Hooker   [Dec 29, 2000, 1.82m, 97kg]
# 20           Francois Cros  Blindside Flanker  [Mar 25, 1994, 1.90m, 107kg]
# 21           Simon Daroque         Scrum Half    [Jun 8, 2005, 1.75m, 74kg]
# 22         Dimitri Delibes      Inside Centre   [Mar 17, 1999, 1.90m, 94kg]
# 24          Antoine Dupont         Scrum Half   [Nov 15, 1996, 1.74m, 85kg]
# 25            Efrain Elias          No 5 Lock  [Apr 30, 2004, 2.01m, 113kg]
# 26             Nelson Epee          Left Wing   [Feb 20, 2001, 1.74m, 73kg]
# 27         Thibaud Flament  Blindside Flanker  [Apr 29, 1997, 2.03m, 116kg]
# 28         Kalvin Gourgues      Inside Centre   [Mar 27, 2005, 1.84m, 93kg]
# 29              Paul Graou         Scrum Half   [Jul 25, 1997, 1.77m, 90kg]
# 30          Malachi Hawkes     Tighthead Prop   [Dec 6, 2002, 1.79m, 123kg]
# 31       Theo Idjellidaine         Scrum Half   [Mar 15, 2001, 1.68m, 79kg]
# 32         Anthony Jelonch              No. 8  [Jul 28, 1996, 1.93m, 105kg]
# 33           Lomig Jouanny      Inside Centre   [May 25, 2004, 1.93m, 87kg]
# 34            Jerome Kaino              Coach   [Apr 6, 1983, 1.96m, 106kg]
# 35          Blair Kinghorn           Fullback  [Jan 18, 1997, 1.93m, 107kg]
# 37         Thomas Lacombre             Hooker   [Jul 14, 2004, 1.74m, 90kg]
# 38            Nepo Laulala     Tighthead Prop   [Nov 6, 1991, 1.84m, 133kg]
# 39           Matthis Lebel         Right Wing   [Mar 25, 1999, 1.84m, 84kg]
# 41             Paul Mallez     Tighthead Prop  [Jan 24, 2001, 1.80m, 116kg]
# 42        Juan Cruz Mallia     Outside Centre   [Sep 11, 1996, 1.82m, 92kg]
# 43         Julien Marchand             Hooker   [Oct 5, 1995, 1.81m, 108kg]
# 44           Peato Mauvaka             Hooker  [Jan 10, 1997, 1.84m, 124kg]
# 45         Emmanuel Meafou          No 5 Lock  [Jul 12, 1998, 2.03m, 140kg]
# 46            Joel Merkler          No 4 Lock  [Oct 25, 2001, 1.94m, 113kg]
# 47                Ugo Mola         Head Coach   [May 14, 1973, 1.83m, 85kg]
# 48           Rodrigue Neti     Loosehead Prop  [Apr 26, 1995, 1.85m, 124kg]
# 49            Theo Ntamack              No. 8  [May 29, 2002, 1.93m, 103kg]
# 50          Romain Ntamack           Fly Half    [May 1, 1999, 1.86m, 86kg]
# 51          Alban Placines  Blindside Flanker  [Apr 23, 1993, 1.89m, 110kg]
# 52      Clement Poitrenaud    Assistant Coach   [May 20, 1982, 1.88m, 90kg]
# 53          Raphael Portat          No 5 Lock  [Oct 25, 2003, 2.00m, 107kg]
# 55            Thomas Ramos           Fullback   [Jul 23, 1995, 1.78m, 87kg]
# 56            Hugo Reilhes     Loosehead Prop   [Jan 1, 2001, 1.80m, 108kg]
# 58           Romain Riguet      Inside Centre   [Apr 10, 2001, 1.84m, 82kg]
# 59        Alexandre Roumat              No. 8  [Jun 24, 1997, 1.98m, 105kg]
# 60             Naoto Saito         Scrum Half   [Aug 26, 1997, 1.65m, 73kg]
# 61       Selevasio Tolofua              No. 8  [May 31, 1997, 1.86m, 116kg]
# 62           Clement Verge     Loosehead Prop  [Sep 13, 2001, 2.00m, 116kg]
# 64             Jack Willis   Openside Flanker  [Dec 24, 1996, 1.90m, 107kg]
#
#     Age Taille (m) Poids (kg)
# 0    33       1.89         96
# 1    26       1.78        125
# 4    32       1.80        119
# 5    35       2.08        127
# 6    26       1.90        100
# 7    32       1.82        116
# 8    23       1.91        112
# 9    27       1.87        102
# 11   30       1.94        112
# 12   30       1.82         88
# 13   47       1.93        100
# 14   24       1.99        114
# 15   26       1.77         82
# 16   21       1.92        105
# 17   26       1.88         96
# 18   22       1.82         85
# 19   25       1.82         97
# 20   31       1.90        107
# 21   20       1.75         74
# 22   26       1.90         94
# 24   29       1.74         85
# 25   21       2.01        113
# 26   24       1.74         73
# 27   28       2.03        116
# 28   20       1.84         93
# 29   28       1.77         90
# 30   23       1.79        123
# 31   24       1.68         79
# 32   29       1.93        105
# 33   21       1.93         87
# 34   42       1.96        106
# 35   28       1.93        107
# 37   21       1.74         90
# 38   34       1.84        133
# 39   26       1.84         84
# 41   24       1.80        116
# 42   29       1.82         92
# 43   30       1.81        108
# 44   28       1.84        124
# 45   27       2.03        140
# 46   24       1.94        113
# 47   52       1.83         85
# 48   30       1.85        124
# 49   23       1.93        103
# 50   26       1.86         86
# 51   32       1.89        110
# 52   43       1.88         90
# 53   22       2.00        107
# 55   30       1.78         87
# 56   24       1.80        108
# 58   24       1.84         82
# 59   28       1.98        105
# 60   28       1.65         73
# 61   28       1.86        116
# 62   24       2.00        116
# 64   29       1.90        107

# %%
fn_df_club('france')
# Out:
#                       Nom              Poste                         Stats  \
# 0          Esteban Abadie  Blindside Flanker   [Dec 1, 1997, 1.88m, 100kg]
# 1        Dorian Aldegheri     Tighthead Prop   [Aug 4, 1993, 1.80m, 119kg]
# 2        Gregory Alldritt              No. 8  [Mar 23, 1997, 1.91m, 113kg]
# 3             Uini Atonio     Tighthead Prop  [Mar 26, 1990, 1.96m, 145kg]
# 4         Theo Attissogbe           Fullback   [Nov 19, 2004, 1.81m, 79kg]
# 5            Hugo Auradou          No 5 Lock  [Jul 20, 2003, 2.00m, 100kg]
# 6            Cyril Baille     Loosehead Prop  [Sep 15, 1993, 1.82m, 116kg]
# 7    Pierre-Louis Barassi     Outside Centre  [Apr 22, 1998, 1.87m, 102kg]
# 8               Leo Barre           Fly Half   [Aug 20, 2002, 1.89m, 89kg]
# 9            Giorgi Beria     Tighthead Prop  [Nov 11, 1999, 1.75m, 108kg]
# 10   Louis Bielle-Biarrey          Left Wing   [Jun 19, 2003, 1.84m, 79kg]
# 11         Paul Boudehent  Blindside Flanker   [Nov 21, 1999, 1.92m, 99kg]
# 12         Joshua Brennan          No 5 Lock  [Nov 28, 2001, 1.99m, 114kg]
# 13  Georges-Henri Colombe     Tighthead Prop   [Apr 9, 1998, 1.93m, 142kg]
# 14          Francois Cros  Blindside Flanker  [Mar 25, 1994, 1.90m, 107kg]
# 15     Nicolas Depoortere     Outside Centre    [Jan 1, 2003, 1.93m, 87kg]
# 16             Gael Drean          Left Wing   [Oct 22, 2000, 1.84m, 84kg]
# 17         Antoine Dupont         Scrum Half   [Nov 15, 1996, 1.74m, 85kg]
# 18        Thibaud Flament  Blindside Flanker  [Apr 29, 1997, 2.03m, 116kg]
# 19         Antoine Frisch      Inside Centre   [Jun 1, 1996, 1.88m, 100kg]
# 20      Emilien Gailleton           Fullback   [Jul 13, 2003, 1.85m, 89kg]
# 21         Fabien Galthié         Head Coach   [Mar 20, 1969, 1.80m, 85kg]
# 22         Marko Gazzotti  Blindside Flanker  [Sep 24, 2004, 1.92m, 107kg]
# 23     Jean-Baptiste Gros     Loosehead Prop  [May 29, 1999, 1.95m, 110kg]
# 24       Mickael Guillard          No 5 Lock  [Dec 10, 2000, 1.97m, 112kg]
# 25      Matthias Halagahu          No 4 Lock  [Aug 15, 2001, 1.94m, 113kg]
# 26         Raphael Ibanez              Coach  [Feb 17, 1973, 1.78m, 100kg]
# 27      Matthieu Jalibert           Fly Half    [Nov 6, 1998, 1.84m, 84kg]
# 28            Oscar Jegou          Left Wing   [May 31, 2003, 1.88m, 84kg]
# 29        Anthony Jelonch              No. 8  [Jul 28, 1996, 1.93m, 105kg]
# 31         Maxime Lamothe             Hooker   [Oct 3, 1998, 1.83m, 109kg]
# 32       Nolann Le Garrec         Scrum Half   [May 14, 2002, 1.75m, 75kg]
# 33            Maxime Lucu         Scrum Half   [Jan 12, 1993, 1.77m, 91kg]
# 34        Julien Marchand             Hooker   [Oct 5, 1995, 1.81m, 108kg]
# 35          Peato Mauvaka             Hooker  [Jan 10, 1997, 1.84m, 124kg]
# 36        Emmanuel Meafou          No 5 Lock  [Jul 12, 1998, 2.03m, 140kg]
# 37          Yoram Moefana     Outside Centre   [Jul 18, 2000, 1.82m, 97kg]
# 38              Noah Nene     Outside Centre   [Oct 14, 2004, 1.87m, 95kg]
# 39         Romain Ntamack           Fly Half    [May 1, 1999, 1.86m, 86kg]
# 40          Damian Penaud         Right Wing   [Sep 25, 1996, 1.92m, 94kg]
# 41             Dany Priso     Loosehead Prop   [Jan 2, 1994, 1.82m, 110kg]
# 42           Thomas Ramos           Fullback   [Jul 23, 1995, 1.78m, 87kg]
# 43       Alexandre Roumat              No. 8  [Jun 24, 1997, 1.98m, 105kg]
# 44         William Servat             Hooker  [Sep 12, 1978, 1.83m, 103kg]
# 45          Rabah Slimani     Tighthead Prop  [Oct 18, 1989, 1.78m, 118kg]
# 46      Romain Taofifenua          No 4 Lock  [Sep 14, 1990, 2.03m, 135kg]
# 47         Gabin Villiere         Right Wing   [Dec 13, 1995, 1.80m, 93kg]
#
#     Age Taille (m) Poids (kg)
# 0    28       1.88        100
# 1    32       1.80        119
# 2    28       1.91        113
# 3    35       1.96        145
# 4    21       1.81         79
# 5    22       2.00        100
# 6    32       1.82        116
# 7    27       1.87        102
# 8    23       1.89         89
# 9    26       1.75        108
# 10   22       1.84         79
# 11   26       1.92         99
# 12   24       1.99        114
# 13   27       1.93        142
# 14   31       1.90        107
# 15   22       1.93         87
# 16   25       1.84         84
# 17   29       1.74         85
# 18   28       2.03        116
# 19   29       1.88        100
# 20   22       1.85         89
# 21   56       1.80         85
# 22   21       1.92        107
# 23   26       1.95        110
# 24   25       1.97        112
# 25   24       1.94        113
# 26   52       1.78        100
# 27   27       1.84         84
# 28   22       1.88         84
# 29   29       1.93        105
# 31   27       1.83        109
# 32   23       1.75         75
# 33   32       1.77         91
# 34   30       1.81        108
# 35   28       1.84        124
# 36   27       2.03        140
# 37   25       1.82         97
# 38   21       1.87         95
# 39   26       1.86         86
# 40   29       1.92         94
# 41   31       1.82        110
# 42   30       1.78         87
# 43   28       1.98        105
# 44   47       1.83        103
# 45   36       1.78        118
# 46   35       2.03        135
# 47   30       1.80         93

# %%
df_rugby['Stats'][0][0].split(',')
# Out:
# ['Sep 24', ' 1992']

# %%
df_rugby = df_rugby.dropna()

# %%
df_rugby['Age'] = df_rugby['Stats'].apply(lambda x : 2025 - int(x[0][-4:]))
df_rugby
# Out:
#                        Nom              Poste                         Stats  \
# 0                Pita Ahki      Inside Centre   [Sep 24, 1992, 1.89m, 96kg]
# 1             David Ainu'u     Loosehead Prop  [Nov 20, 1999, 1.78m, 125kg]
# 4         Dorian Aldegheri     Tighthead Prop   [Aug 4, 1993, 1.80m, 119kg]
# 5            Richie Arnold          No 5 Lock   [Jul 1, 1990, 2.08m, 127kg]
# 6              Paul Ausset              No. 8  [Jun 19, 1999, 1.90m, 100kg]
# 7             Cyril Baille     Loosehead Prop  [Sep 15, 1993, 1.82m, 116kg]
# 8                Leo Banos   Openside Flanker  [Aug 16, 2002, 1.91m, 112kg]
# 9     Pierre-Louis Barassi     Outside Centre  [Apr 22, 1998, 1.87m, 102kg]
# 11     Setareki Bituniyata     Outside Centre  [Aug 12, 1995, 1.94m, 112kg]
# 12         Arthur Bonneval          Left Wing   [May 31, 1995, 1.82m, 88kg]
# 13           Jean Bouilhou    Assistant Coach   [Dec 1, 1978, 1.93m, 100kg]
# 14          Joshua Brennan          No 5 Lock  [Nov 28, 2001, 1.99m, 114kg]
# 15           Ange Capuozzo           Fullback   [Apr 30, 1999, 1.77m, 82kg]
# 16  Mathis Castro Ferreira          Left Wing  [Jan 13, 2004, 1.92m, 105kg]
# 17     Santiago Chocobares     Outside Centre   [Mar 31, 1999, 1.88m, 96kg]
# 18             Paul Costes      Inside Centre    [Apr 4, 2003, 1.82m, 85kg]
# 19       Guillaume Cramont             Hooker   [Dec 29, 2000, 1.82m, 97kg]
# 20           Francois Cros  Blindside Flanker  [Mar 25, 1994, 1.90m, 107kg]
# 22         Dimitri Delibes      Inside Centre   [Mar 17, 1999, 1.90m, 94kg]
# 24          Antoine Dupont         Scrum Half   [Nov 15, 1996, 1.74m, 85kg]
# 25            Efrain Elias          No 5 Lock  [Apr 30, 2004, 2.01m, 113kg]
# 26             Nelson Epee          Left Wing   [Feb 20, 2001, 1.74m, 73kg]
# 27         Thibaud Flament  Blindside Flanker  [Apr 29, 1997, 2.03m, 116kg]
# 28         Kalvin Gourgues      Inside Centre   [Mar 27, 2005, 1.84m, 93kg]
# 29              Paul Graou         Scrum Half   [Jul 25, 1997, 1.77m, 90kg]
# 30          Malachi Hawkes     Tighthead Prop   [Dec 6, 2002, 1.79m, 123kg]
# 31       Theo Idjellidaine         Scrum Half   [Mar 15, 2001, 1.68m, 79kg]
# 32         Anthony Jelonch              No. 8  [Jul 28, 1996, 1.93m, 105kg]
# 33           Lomig Jouanny      Inside Centre   [May 25, 2004, 1.93m, 87kg]
# 34            Jerome Kaino              Coach   [Apr 6, 1983, 1.96m, 106kg]
# 35          Blair Kinghorn           Fullback  [Jan 18, 1997, 1.93m, 107kg]
# 37         Thomas Lacombre             Hooker   [Jul 14, 2004, 1.74m, 90kg]
# 38            Nepo Laulala     Tighthead Prop   [Nov 6, 1991, 1.84m, 133kg]
# 39           Matthis Lebel         Right Wing   [Mar 25, 1999, 1.84m, 84kg]
# 41             Paul Mallez     Tighthead Prop  [Jan 24, 2001, 1.80m, 116kg]
# 42        Juan Cruz Mallia     Outside Centre   [Sep 11, 1996, 1.82m, 92kg]
# 43         Julien Marchand             Hooker   [Oct 5, 1995, 1.81m, 108kg]
# 44           Peato Mauvaka             Hooker  [Jan 10, 1997, 1.84m, 124kg]
# 45         Emmanuel Meafou          No 5 Lock  [Jul 12, 1998, 2.03m, 140kg]
# 46            Joel Merkler          No 4 Lock  [Oct 25, 2001, 1.94m, 113kg]
# 47                Ugo Mola         Head Coach   [May 14, 1973, 1.83m, 85kg]
# 48           Rodrigue Neti     Loosehead Prop  [Apr 26, 1995, 1.85m, 124kg]
# 49            Theo Ntamack              No. 8  [May 29, 2002, 1.93m, 103kg]
# 50          Romain Ntamack           Fly Half    [May 1, 1999, 1.86m, 86kg]
# 51          Alban Placines  Blindside Flanker  [Apr 23, 1993, 1.89m, 110kg]
# 52      Clement Poitrenaud    Assistant Coach   [May 20, 1982, 1.88m, 90kg]
# 53          Raphael Portat          No 5 Lock  [Oct 25, 2003, 2.00m, 107kg]
# 55            Thomas Ramos           Fullback   [Jul 23, 1995, 1.78m, 87kg]
# 56            Hugo Reilhes     Loosehead Prop   [Jan 1, 2001, 1.80m, 108kg]
# 58           Romain Riguet      Inside Centre   [Apr 10, 2001, 1.84m, 82kg]
# 59        Alexandre Roumat              No. 8  [Jun 24, 1997, 1.98m, 105kg]
# 60             Naoto Saito         Scrum Half   [Aug 26, 1997, 1.65m, 73kg]
# 61       Selevasio Tolofua              No. 8  [May 31, 1997, 1.86m, 116kg]
# 62           Clement Verge     Loosehead Prop  [Sep 13, 2001, 2.00m, 116kg]
# 64             Jack Willis   Openside Flanker  [Dec 24, 1996, 1.90m, 107kg]
#
#     Age
# 0    33
# 1    26
# 4    32
# 5    35
# 6    26
# 7    32
# 8    23
# 9    27
# 11   30
# 12   30
# 13   47
# 14   24
# 15   26
# 16   21
# 17   26
# 18   22
# 19   25
# 20   31
# 22   26
# 24   29
# 25   21
# 26   24
# 27   28
# 28   20
# 29   28
# 30   23
# 31   24
# 32   29
# 33   21
# 34   42
# 35   28
# 37   21
# 38   34
# 39   26
# 41   24
# 42   29
# 43   30
# 44   28
# 45   27
# 46   24
# 47   52
# 48   30
# 49   23
# 50   26
# 51   32
# 52   43
# 53   22
# 55   30
# 56   24
# 58   24
# 59   28
# 60   28
# 61   28
# 62   24
# 64   29

# %%
df_rugby_nona['Taille (m)'] = df_rugby_nona['Stats'].apply(lambda x : (x[1][0:4]))
df_rugby_nona.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df_rugby_nona['Taille (m)'] = df_rugby_nona['Stats'].apply(lambda x : (x[1][0:4]))
#       2 df_rugby_nona.head(2)
#
# NameError: name 'df_rugby_nona' is not defined

# %%
df_rugby_nona['Taille (m)'] = df_rugby_nona['Stats'].apply(lambda x : x.
# Out:
#   Cell In[13], line 1
#     df_rugby_nona['Taille (m)'] = df_rugby_nona['Stats'].apply(lambda x : x.
#                                                                             ^
# SyntaxError: incomplete input

# %%
df_rugby_nona['Poids (kg)'] = df_rugby_nona['Stats'].apply(lambda x : (x[2][0:-2]))
df_rugby_nona.head(2)
# Out:
# C:\Users\wilder_new\AppData\Local\Temp\ipykernel_28124\3548528475.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rugby_nona['Poids (kg)'] = df_rugby_nona['Stats'].apply(lambda x : (x[2][0:-2]))
#             Nom           Poste                         Stats  Age Taille (m)  \
# 0     Pita Ahki   Inside Centre   [Sep 24, 1992, 1.89m, 96kg]   33       1.89
# 1  David Ainu'u  Loosehead Prop  [Nov 20, 1999, 1.78m, 125kg]   26       1.78
#
#   Poids (kg)
# 0         96
# 1        125

# %%
df_rugby_nona['Poids (kg)'] = df_rugby_nona['Poids (kg)'].astype('int32')
df_rugby_nona.head(2)
# Out:
# C:\Users\wilder_new\AppData\Local\Temp\ipykernel_28124\888836486.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rugby_nona['Poids (kg)'] = df_rugby_nona['Poids (kg)'].astype('int32')
#             Nom           Poste                         Stats  Age Taille (m)  \
# 0     Pita Ahki   Inside Centre   [Sep 24, 1992, 1.89m, 96kg]   33       1.89
# 1  David Ainu'u  Loosehead Prop  [Nov 20, 1999, 1.78m, 125kg]   26       1.78
#
#    Poids (kg)
# 0          96
# 1         125

# %%
df_rugby_nona
# Out:
#                        Nom              Poste                         Stats  \
# 0                Pita Ahki      Inside Centre   [Sep 24, 1992, 1.89m, 96kg]
# 1             David Ainu'u     Loosehead Prop  [Nov 20, 1999, 1.78m, 125kg]
# 4         Dorian Aldegheri     Tighthead Prop   [Aug 4, 1993, 1.80m, 119kg]
# 5            Richie Arnold          No 5 Lock   [Jul 1, 1990, 2.08m, 127kg]
# 6              Paul Ausset              No. 8  [Jun 19, 1999, 1.90m, 100kg]
# 7             Cyril Baille     Loosehead Prop  [Sep 15, 1993, 1.82m, 116kg]
# 8                Leo Banos   Openside Flanker  [Aug 16, 2002, 1.91m, 112kg]
# 9     Pierre-Louis Barassi     Outside Centre  [Apr 22, 1998, 1.87m, 102kg]
# 11     Setareki Bituniyata     Outside Centre  [Aug 12, 1995, 1.94m, 112kg]
# 12         Arthur Bonneval          Left Wing   [May 31, 1995, 1.82m, 88kg]
# 13           Jean Bouilhou    Assistant Coach   [Dec 1, 1978, 1.93m, 100kg]
# 14          Joshua Brennan          No 5 Lock  [Nov 28, 2001, 1.99m, 114kg]
# 15           Ange Capuozzo           Fullback   [Apr 30, 1999, 1.77m, 82kg]
# 16  Mathis Castro Ferreira          Left Wing  [Jan 13, 2004, 1.92m, 105kg]
# 17     Santiago Chocobares     Outside Centre   [Mar 31, 1999, 1.88m, 96kg]
# 18             Paul Costes      Inside Centre    [Apr 4, 2003, 1.82m, 85kg]
# 19       Guillaume Cramont             Hooker   [Dec 29, 2000, 1.82m, 97kg]
# 20           Francois Cros  Blindside Flanker  [Mar 25, 1994, 1.90m, 107kg]
# 22         Dimitri Delibes      Inside Centre   [Mar 17, 1999, 1.90m, 94kg]
# 24          Antoine Dupont         Scrum Half   [Nov 15, 1996, 1.74m, 85kg]
# 25            Efrain Elias          No 5 Lock  [Apr 30, 2004, 2.01m, 113kg]
# 26             Nelson Epee          Left Wing   [Feb 20, 2001, 1.74m, 73kg]
# 27         Thibaud Flament  Blindside Flanker  [Apr 29, 1997, 2.03m, 116kg]
# 28         Kalvin Gourgues      Inside Centre   [Mar 27, 2005, 1.84m, 93kg]
# 29              Paul Graou         Scrum Half   [Jul 25, 1997, 1.77m, 90kg]
# 30          Malachi Hawkes     Tighthead Prop   [Dec 6, 2002, 1.79m, 123kg]
# 31       Theo Idjellidaine         Scrum Half   [Mar 15, 2001, 1.68m, 79kg]
# 32         Anthony Jelonch              No. 8  [Jul 28, 1996, 1.93m, 105kg]
# 33           Lomig Jouanny      Inside Centre   [May 25, 2004, 1.93m, 87kg]
# 34            Jerome Kaino              Coach   [Apr 6, 1983, 1.96m, 106kg]
# 35          Blair Kinghorn           Fullback  [Jan 18, 1997, 1.93m, 107kg]
# 37         Thomas Lacombre             Hooker   [Jul 14, 2004, 1.74m, 90kg]
# 38            Nepo Laulala     Tighthead Prop   [Nov 6, 1991, 1.84m, 133kg]
# 39           Matthis Lebel         Right Wing   [Mar 25, 1999, 1.84m, 84kg]
# 41             Paul Mallez     Tighthead Prop  [Jan 24, 2001, 1.80m, 116kg]
# 42        Juan Cruz Mallia     Outside Centre   [Sep 11, 1996, 1.82m, 92kg]
# 43         Julien Marchand             Hooker   [Oct 5, 1995, 1.81m, 108kg]
# 44           Peato Mauvaka             Hooker  [Jan 10, 1997, 1.84m, 124kg]
# 45         Emmanuel Meafou          No 5 Lock  [Jul 12, 1998, 2.03m, 140kg]
# 46            Joel Merkler          No 4 Lock  [Oct 25, 2001, 1.94m, 113kg]
# 47                Ugo Mola         Head Coach   [May 14, 1973, 1.83m, 85kg]
# 48           Rodrigue Neti     Loosehead Prop  [Apr 26, 1995, 1.85m, 124kg]
# 49            Theo Ntamack              No. 8  [May 29, 2002, 1.93m, 103kg]
# 50          Romain Ntamack           Fly Half    [May 1, 1999, 1.86m, 86kg]
# 51          Alban Placines  Blindside Flanker  [Apr 23, 1993, 1.89m, 110kg]
# 52      Clement Poitrenaud    Assistant Coach   [May 20, 1982, 1.88m, 90kg]
# 53          Raphael Portat          No 5 Lock  [Oct 25, 2003, 2.00m, 107kg]
# 55            Thomas Ramos           Fullback   [Jul 23, 1995, 1.78m, 87kg]
# 56            Hugo Reilhes     Loosehead Prop   [Jan 1, 2001, 1.80m, 108kg]
# 58           Romain Riguet      Inside Centre   [Apr 10, 2001, 1.84m, 82kg]
# 59        Alexandre Roumat              No. 8  [Jun 24, 1997, 1.98m, 105kg]
# 60             Naoto Saito         Scrum Half   [Aug 26, 1997, 1.65m, 73kg]
# 61       Selevasio Tolofua              No. 8  [May 31, 1997, 1.86m, 116kg]
# 62           Clement Verge     Loosehead Prop  [Sep 13, 2001, 2.00m, 116kg]
# 64             Jack Willis   Openside Flanker  [Dec 24, 1996, 1.90m, 107kg]
#
#     Age Taille (m)  Poids (kg)
# 0    33       1.89          96
# 1    26       1.78         125
# 4    32       1.80         119
# 5    35       2.08         127
# 6    26       1.90         100
# 7    32       1.82         116
# 8    23       1.91         112
# 9    27       1.87         102
# 11   30       1.94         112
# 12   30       1.82          88
# 13   47       1.93         100
# 14   24       1.99         114
# 15   26       1.77          82
# 16   21       1.92         105
# 17   26       1.88          96
# 18   22       1.82          85
# 19   25       1.82          97
# 20   31       1.90         107
# 22   26       1.90          94
# 24   29       1.74          85
# 25   21       2.01         113
# 26   24       1.74          73
# 27   28       2.03         116
# 28   20       1.84          93
# 29   28       1.77          90
# 30   23       1.79         123
# 31   24       1.68          79
# 32   29       1.93         105
# 33   21       1.93          87
# 34   42       1.96         106
# 35   28       1.93         107
# 37   21       1.74          90
# 38   34       1.84         133
# 39   26       1.84          84
# 41   24       1.80         116
# 42   29       1.82          92
# 43   30       1.81         108
# 44   28       1.84         124
# 45   27       2.03         140
# 46   24       1.94         113
# 47   52       1.83          85
# 48   30       1.85         124
# 49   23       1.93         103
# 50   26       1.86          86
# 51   32       1.89         110
# 52   43       1.88          90
# 53   22       2.00         107
# 55   30       1.78          87
# 56   24       1.80         108
# 58   24       1.84          82
# 59   28       1.98         105
# 60   28       1.65          73
# 61   28       1.86         116
# 62   24       2.00         116
# 64   29       1.90         107

# %%
display(df_rugby_nona['Age'].mean(),
        df_rugby_nona['Taille (m)'].mean(),
        df_rugby_nona['Poids (kg)'].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[154], line 2
#       1 display(df_rugby_nona['Age'].mean(),
# ----> 2         df_rugby_nona['Taille (m)'].mean(),
#       3         df_rugby_nona['Poids (kg)'].mean())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12373 nv.validate_func(name, (), kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6452     # GH#47500 - change to TypeError to match other methods
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1698 elif not (is_float(x) or is_integer(x) or is_complex(x)):
#    1699     if isinstance(x, str):
#    1700         # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701         raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702     try:
#    1703         x = float(x)
#
# TypeError: Could not convert string '1.891.781.802.081.901.821.911.871.941.821.931.991.771.921.881.821.821.901.901.742.011.742.031.841.771.791.681.931.931.961.931.741.841.841.801.821.811.842.031.941.831.851.931.861.891.882.001.781.801.841.981.651.862.001.90' to numeric

# %%
float(df_rugby_nona['Taille (m)'][0].replace(',', '.'))
# Out:
# 1.88

# %%
aa

# %%
# equipe = input()

# url = f'https://www.ultimaterugby.com/app/public/index.php/{equipe}/squad'

# html = requests.get(url)

# soup = BeautifulSoup(html.text, 'html.parser')

# test = soup.find_all('div', {"class" : "col-md-2 col-sm-4 col-xs-6"})

# for player in range(len(test)):
#     print(str(test[player].find_all('h4')[0].get_text(separator='<br/>')).replace("<br/>"," "))

# %%
# date = input('Insérez une date au format (AAAA-MM-JJ) : ')

equipe = 'Stade Rochelais'

# url_top14 = f'https://api.sofascore.com/api/v1/sport/rugby/scheduled-events/{date}'
url_top14 = f'https://api.sofascore.com/api/v1/sport/rugby/scheduled-events/2024-11-30'

# Effectuer une requête à l'API
r = requests.get(url_top14)
data = r.json()

# pprint(data['events'][0])

# int(len(data['events']))

for team in range(len(data['events'])):
#     pprint(data['events'][away_teams]['awayTeam']['name'])
    if data['events'][team]['awayTeam']['name'] == equipe:
        # pprint(data['events'][away_teams]['awayTeam']['name'])
        num_match = team
    elif data['events'][team]['homeTeam']['name'] == equipe:
        # pprint(data['events'][away_teams]['awayTeam']['name'])
        num_match = team

# Score équipe à domicile
print(f"Equipe à domicile : {data['events'][num_match]['homeTeam']['name']}")        
pprint(data['events'][num_match]['homeScore']['normaltime'])
# Score équipe extérieur
print(f"Equipe à l\'extérieur : {data['events'][num_match]['awayTeam']['name']}")  
pprint(data['events'][num_match]['awayScore']['normaltime'])
# Out:
# Equipe à domicile : Stade Rochelais
# 15
# Equipe à l'extérieur : RC Vannes
# 23

# %%
pprint(data['events'][9])
# Out:
# {'awayScore': {'current': 12,
#                'display': 13,
#                'normaltime': 12,
#                'period1': 5,
#                'period2': 7},
#  'awayTeam': {'country': {},
#               'entityType': 'team',
#               'fieldTranslations': {'nameTranslation': {'ar': 'ساراسنز',
#                                                         'bn': 'সারাসেনস',
#                                                         'hi': 'सारासेंस',
#                                                         'ru': 'Сарацины'},
#                                     'shortNameTranslation': {'ar': 'ساراسنز',
#                                                              'bn': 'সারাসেনস',
#                                                              'hi': 'सारासेंस'}},
#               'gender': 'M',
#               'id': 4197,
#               'name': 'Saracens',
#               'nameCode': 'SAR',
#               'national': True,
#               'shortName': 'Saracens',
#               'slug': 'saracens',
#               'sport': {'id': 12, 'name': 'Rugby', 'slug': 'rugby'},
#               'subTeams': [],
#               'teamColors': {'primary': '#374df5',
#                              'secondary': '#374df5',
#                              'text': '#ffffff'},
#               'type': 0,
#               'userCount': 1547},
#  'changes': {'changeTimestamp': 1732916146,
#              'changes': ['time.currentPeriodStart',
#                          'status.code',
#                          'status.description',
#                          'status.type',
#                          'homeScore.normaltime',
#                          'awayScore.normaltime']},
#  'crowdsourcingDataDisplayEnabled': True,
#  'customId': 'RIbsUIb',
#  'feedLocked': False,
#  'finalResultOnly': True,
#  'hasEventPlayerStatistics': True,
#  'hasGlobalHighlights': False,
#  'homeScore': {'current': 17,
#                'display': 18,
#                'normaltime': 17,
#                'period1': 18,
#                'period2': 0},
#  'homeTeam': {'country': {},
#               'disabled': True,
#               'entityType': 'team',
#               'fieldTranslations': {'nameTranslation': {'ar': 'نيوكاسل فالكونز',
#                                                         'bn': 'নিউক্যাসল '
#                                                               'ফ্যালকনস',
#                                                         'hi': 'न्यूकैसल '
#                                                               'फाल्कन्स',
#                                                         'ru': 'Ньюкасл '
#                                                               'Фэлконс'},
#                                     'shortNameTranslation': {'ar': 'نيوكاسل',
#                                                              'bn': 'নিউক্যাসল',
#                                                              'hi': 'न्यूकैसल'}},
#               'gender': 'M',
#               'id': 4192,
#               'name': 'Newcastle Falcons',
#               'nameCode': 'NCF',
#               'national': True,
#               'shortName': 'Newcastle',
#               'slug': 'newcastle-falcons',
#               'sport': {'id': 12, 'name': 'Rugby', 'slug': 'rugby'},
#               'subTeams': [],
#               'teamColors': {'primary': '#374df5',
#                              'secondary': '#374df5',
#                              'text': '#ffffff'},
#               'type': 0,
#               'userCount': 545},
#  'id': 12593606,
#  'isEditor': False,
#  'roundInfo': {'round': 7},
#  'season': {'editor': False,
#             'id': 64381,
#             'name': 'English Premiership 24/25',
#             'year': '24/25'},
#  'slug': 'saracens-newcastle-falcons',
#  'startTimestamp': 1732905000,
#  'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#  'time': {'currentPeriodStartTimestamp': 1732916141,
#           'overtimeLength': 600,
#           'periodLength': 2401,
#           'played': 4800,
#           'totalPeriodCount': 2},
#  'tournament': {'category': {'country': {},
#                              'flag': 'rugby-union',
#                              'id': 82,
#                              'name': 'Rugby Union',
#                              'slug': 'rugby-union',
#                              'sport': {'id': 12,
#                                        'name': 'Rugby',
#                                        'slug': 'rugby'}},
#                 'fieldTranslations': {'nameTranslation': {'ar': 'الدوري '
#                                                                 'الإنجليزي '
#                                                                 'الممتاز',
#                                                           'bn': 'ইংলিশ '
#                                                                 'প্রিমিয়ারশিপ',
#                                                           'hi': 'इंग्लिश '
#                                                                 'प्रीमियरशिप'},
#                                       'shortNameTranslation': {}},
#                 'id': 54520,
#                 'name': 'English Premiership',
#                 'priority': 0,
#                 'slug': 'english-premiership',
#                 'uniqueTournament': {'category': {'country': {},
#                                                   'flag': 'rugby-union',
#                                                   'id': 82,
#                                                   'name': 'Rugby Union',
#                                                   'slug': 'rugby-union',
#                                                   'sport': {'id': 12,
#                                                             'name': 'Rugby',
#                                                             'slug': 'rugby'}},
#                                      'displayInverseHomeAwayTeams': False,
#                                      'fieldTranslations': {'nameTranslation': {'ar': 'الدوري '
#                                                                                      'الإنجليزي '
#                                                                                      'الممتاز '
#                                                                                      'للرغبي',
#                                                                                'bn': 'ইংলিশ '
#                                                                                      'প্রিমিয়ারশিপ',
#                                                                                'hi': 'इंग्लिश '
#                                                                                      'प्रीमियरशिप'},
#                                                            'shortNameTranslation': {}},
#                                      'hasEventPlayerStatistics': True,
#                                      'hasPerformanceGraphFeature': True,
#                                      'id': 424,
#                                      'name': 'English Premiership',
#                                      'slug': 'english-premiership',
#                                      'userCount': 4090}},
#  'winnerCode': 1}

# %%
# Aller scrapper les dates de chaque journée de top 14 (sur le site du top 14)
# Aller scrapper les équipes du top 14 (ultimate rugby ou top 14)
# Récupération des résultats avec l'API sofascore
# Aller scrapper les joueurs (ultimate rugby)
# Récupération des données météo en fonction des dates de matchs et des lieux (équipe à domicile)
# Sidebar avec les 14 équipes ?
# Menu avec le classement en direct et les derniers résultats ? (5)

# %%
# Création des données
data = {
    "latitude": [
        43.6198,  # Stade Ernest-Wallon
        44.8297,  # Stade Chaban-Delmas
        48.8924,  # Paris La Défense Arena
        48.8413,  # Stade Jean-Bouin
        45.7256,  # Stade de Gerland
        45.7860,  # Stade Marcel-Michelin
        43.1167,  # Stade Mayol
        46.1667,  # Stade Marcel-Deflandre
        43.5833,  # GGL Stadium
        42.7108,  # Stade Aimé-Giral
        43.2917,  # Stade du Hameau
        43.4847,  # Stade Jean-Dauger
        43.6031,  # Stade Pierre-Fabre
        47.6550,  # Stade de la Rabine
    ],
    "longitude": [
        1.4093,    # Stade Ernest-Wallon
        -0.5950,   # Stade Chaban-Delmas
        2.2255,    # Paris La Défense Arena
        2.2622,    # Stade Jean-Bouin
        4.8318,    # Stade de Gerland
        3.1090,    # Stade Marcel-Michelin
        5.9310,    # Stade Mayol
        -1.1517,   # Stade Marcel-Deflandre
        3.8480,    # GGL Stadium
        2.8956,    # Stade Aimé-Giral
        -0.3700,   # Stade du Hameau
        -1.4672,   # Stade Jean-Dauger
        2.2436,    # Stade Pierre-Fabre
        -2.7600,   # Stade de la Rabine
    ],
}

# Index : noms des stades
index = [
    "Stade Ernest-Wallon",
    "Stade Chaban-Delmas",
    "Paris La Défense Arena",
    "Stade Jean-Bouin",
    "Stade de Gerland",
    "Stade Marcel-Michelin",
    "Stade Mayol",
    "Stade Marcel-Deflandre",
    "GGL Stadium",
    "Stade Aimé-Giral",
    "Stade du Hameau",
    "Stade Jean-Dauger",
    "Stade Pierre-Fabre",
    "Stade de la Rabine",
]

# Création du DataFrame
df = pd.DataFrame(data, index=index)

# Sauvegarde du DataFrame au format CSV
df.to_csv("stades_top14.csv")

print("Fichier CSV créé avec succès !")
# Out:
# Fichier CSV créé avec succès !

# %%
import random
import numpy as np

df = pd.DataFrame(
    np.random.randn(1000, 2) / [50, 50] + [37.76, -122.4],
    columns=["lat", "lon"]
)

df
# Out:
#            lat         lon
# 0    37.786954 -122.383231
# 1    37.770312 -122.407529
# 2    37.777347 -122.380954
# 3    37.739519 -122.401407
# 4    37.728771 -122.409773
# ..         ...         ...
# 995  37.761855 -122.463402
# 996  37.814930 -122.424052
# 997  37.723337 -122.402013
# 998  37.742485 -122.400875
# 999  37.768710 -122.392553
#
# [1000 rows x 2 columns]

# %%
import pandas as pd

# %%
df_stades= pd.read_csv("stades_top14.csv")

# df_stades.rename(columns={"latitude":"Longitude","Unnamed: 0":"Latitude","longitude":"Clubs"},inplace=True)
# df_stades.rename(columns={"Clubs":"Equipes"},inplace=True)

# %%
df_stades
# Out:
#                 Nom_stades  latitude  longitude                    Equipes
# 0      Stade Ernest-Wallon   43.6198     1.4093                   Toulouse
# 1      Stade Chaban-Delmas   44.8297    -0.5950      Union Bordeaux-Bègles
# 2   Paris La Défense Arena   48.8924     2.2255                  Racing 92
# 3         Stade Jean-Bouin   48.8413     2.2622       Stade Français Paris
# 4         Stade de Gerland   45.7256     4.8318                  LOU Rugby
# 5    Stade Marcel-Michelin   45.7860     3.1090               ASM Clermont
# 6              Stade Mayol   43.1167     5.9310                  RC Toulon
# 7   Stade Marcel-Deflandre   46.1667    -1.1517            Stade Rochelais
# 8              GGL Stadium   43.5833     3.8480  Montpellier Hérault Rugby
# 9    Stade Amédée-Domenech   45.1616     1.5486                   CA Brive
# 10         Stade du Hameau   43.2917    -0.3700            Section Paloise
# ...

# %%
dico_id_club = {'LOU Rugby':1,
                'RC Toulon':2,
                'Section Paloise':3,
                'ASM Clermont':4,
                'Aviron Bayonnais':5,
                'Union Bordeaux-Bègles':6,
                'Castres Olympique':7,
                'Montpellier Hérault Rugby':8,
                'Toulouse':9,
                'Racing 92':10,
                'Stade Rochelais':11,
                'CA Brive':12,
                'SU Agen':13,
                'Stade Français Paris':14,
                'Biarritz Olympique':15,
                'USA Perpignan':16,
                'Oyonnax Rugby':17,
                'RC Vannes':18}

# %%
df_stades["ID_equipes"]= df_stades["Equipes"].apply(lambda x : dico_id_club[x])

# %%
df_stades
# Out:
#                 Nom_stades  latitude  longitude                    Equipes  \
# 0      Stade Ernest-Wallon   43.6198     1.4093                   Toulouse
# 1      Stade Chaban-Delmas   44.8297    -0.5950      Union Bordeaux-Bègles
# 2   Paris La Défense Arena   48.8924     2.2255                  Racing 92
# 3         Stade Jean-Bouin   48.8413     2.2622       Stade Français Paris
# 4         Stade de Gerland   45.7256     4.8318                  LOU Rugby
# 5    Stade Marcel-Michelin   45.7860     3.1090               ASM Clermont
# 6              Stade Mayol   43.1167     5.9310                  RC Toulon
# 7   Stade Marcel-Deflandre   46.1667    -1.1517            Stade Rochelais
# 8              GGL Stadium   43.5833     3.8480  Montpellier Hérault Rugby
# 9    Stade Amédée-Domenech   45.1616     1.5486                   CA Brive
# 10         Stade du Hameau   43.2917    -0.3700            Section Paloise
# ...
